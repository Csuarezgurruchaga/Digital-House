# %%
# initial setup
# %run "../../../common/0_notebooks_base_setup.py"
# Out:
# /Users/csuarezgurruchaga/Desktop/Digital-House/CLASE_28/dsad_2021/common
# default checking
# Running command `conda list`... ok
# jupyterlab=2.2.6 already installed
# pandas=1.1.5 already installed
# bokeh=2.2.3 already installed
# seaborn=0.11.0 already installed
# matplotlib=3.3.2 already installed
# ipywidgets=7.5.1 already installed
# pytest=6.2.1 already installed
# chardet=4.0.0 already installed
# psutil=5.7.2 already installed
# scipy=1.5.2 already installed
# statsmodels=0.12.1 already installed
# scikit-learn=0.23.2 already installed
# xlrd=2.0.1 already installed
# Running command `conda install --yes nltk=3.5.0`... ok
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# unidecode=1.1.1 already installed
# pydotplus=2.0.2 already installed
# pandas-datareader=0.9.0 already installed
# flask=1.1.2 already installed

# %% [markdown]
# <img src="../../../common/logo_DH.png" align='left' width=50%/>

# %%
from checkpoint_logistic_regression import *

# %%
test_1()
# Out:
# Se tiene un conjunto de imágenes médicas en las que aparecen tumores y se quiere automatizar la clasificación de
# los mismos. Sabiendo que pueden ser malignos o benignos, ¿qué tipo de problema es?
# RadioButtons(layout=Layout(width='100%'), options=('Clasificación binaria', 'Clasificación multiclase', 'Clasi…
# Button(description='Validar', style=ButtonStyle(), tooltip='Click para validar')
# Output()

# %%
test_2()
# Out:
# Un banco posee un detector de clientes fraudulentos que clasifica a las operaciones como "legales" (0) o
# "sospechosas" (1).
# Últimamente, varias operaciones legales fueron clasificadas como sospechosas, haciendo que el banco pierda tiempo
# y dinero investigando operaciones legales.
# Como responsable del área de Data Science, te exigen una solución rápida. ¿Cuál de estas alternativas probarías
# primero?
# RadioButtons(layout=Layout(width='100%'), options=('Recolectar datos nuevos y reentrenar el modelo', 'Elevar e…
# Button(description='Validar', style=ButtonStyle(), tooltip='Click para validar')
# Output()

# %%
test_3()
# Out:
# ¿Cuál de estas funciones es la que se utiliza para estimar la probabilidad de que una observación pertenezca a una clase?
# RadioButtons(layout=Layout(width='100%'), options=('Sigmoide', 'ReLu', 'tanh', 'lineal'), value='Sigmoide')
# Button(description='Validar', style=ButtonStyle(), tooltip='Click para validar')
# Output()

# %%
test_4()
# Out:
# Dado un problema de clasificación binaria donde las observaciones tienen 2 features x1 y x2, graficamos los datos
# y obtenemos la siguiente distribución. ¿Podemos utilizar una regresión logística sobre este dataset?
# RadioButtons(layout=Layout(width='100%'), options=('Sí.', 'No.'), value='Sí.')
# Button(description='Validar', style=ButtonStyle(), tooltip='Click para validar')
# Output()

# %%
test_5()
# Out:
# En los problemas de clasificación, a diferencia de los problemas de regresión:
# RadioButtons(layout=Layout(width='100%'), options=('No hay que preocuparse por el overfitting.', 'No hay que p…
# Button(description='Validar', style=ButtonStyle(), tooltip='Click para validar')
# Output()

# %%
test_6()
# Out:
# Se quiere resolver un problema de clasificación binaria, para lo cual se cuenta con un dataset con 1000 casos de
# entrenamiento (X_train) y 100 casos de test (X_test). Luego de entrenar el modelo con Scikit-Learn, qué output
# tendrá la siguiente línea de código?
# lr.predict_proba(X_test).
# RadioButtons(layout=Layout(width='100%'), options=('(2, 100)', '(100, 2)', '(100, 1)', '(1000,2)', 'No se pued…
# Button(description='Validar', style=ButtonStyle(), tooltip='Click para validar')
# Output()

# %%
test_7()
# Out:
# Luego de ejecutar el siguiente código:
#
# lr = LogisticRegression()
# lr.fit(X,y)
#
# Seleccioná cuáles de las siguientes afirmaciones son correctas, sabiendo que 'y' puede tomar 3 valores
# posbiles:
# Checkbox(value=False, description='lr.predict_proba(X).sum(axis=1) devuelve un array lleno de 1s', indent=Fals…
# Checkbox(value=False, description='lr.predict_proba(X) > 0.5 == lr.predict(X).astype(bool) evalúa siempre posi…
# Checkbox(value=False, description='lr.predict_proba(X).argmax(axis=1) == lr.predict(X) evalúa siempre positivo…
# Checkbox(value=False, description='El código arrojará un error ya que la clase LogisticRegression() sólo admit…
# Button(description='Validar', style=ButtonStyle(), tooltip='Click para validar')
# Output()
