# %%
# initial setup
# %run "../../../common/0_notebooks_base_setup.py"
# Out:
# /Users/csuarezgurruchaga/Desktop/Digital-House/CLASE_38/dsad_2021/common
# default checking
# Running command `conda list`... ok
# Running command `conda install --yes jupyterlab=2.2.6`...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Desktop/Digital-House/CLASE_38/dsad_2021/common/0_notebooks_base_setup.py in <module>
#     125         pass
#     126
# --> 127 main(sys.argv)
#
# ~/Desktop/Digital-House/CLASE_38/dsad_2021/common/0_notebooks_base_setup.py in main(arguments)
#     121     requirements_file_path = '../../../common/requirements.txt'
#     122     try:
# --> 123         install_packages(requirements_file_path)
#     124     except subprocess.CalledProcessError as err:
#     125         pass
#
# ~/Desktop/Digital-House/CLASE_38/dsad_2021/common/0_notebooks_base_setup.py in install_packages(requirements_file_path, channel)
#      93                 command += '-c ' + channel + ' '
#      94             command += package_name
# ---> 95             print(popen(command))
#      96         else:
#      97             print(package_name + ' already installed' )
#
# ~/Desktop/Digital-House/CLASE_38/dsad_2021/common/0_notebooks_base_setup.py in popen(cmd)
#       5     try:
#       6         print(f"Running command `{cmd}`... ", end="")
# ----> 7         proc = subprocess.run(
#       8             cmd,
#       9             shell=True,
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493     with Popen(*popenargs, **kwargs) as process:
#     494         try:
# --> 495             stdout, stderr = process.communicate(input, timeout=timeout)
#     496         except TimeoutExpired as exc:
#     497             process.kill()
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1026
#    1027             try:
# -> 1028                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1029             except KeyboardInterrupt:
#    1030                 # https://bugs.python.org/issue25942
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1868                             'failed to raise TimeoutExpired.')
#    1869
# -> 1870                     ready = selector.select(timeout)
#    1871                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1872
#
# ~/opt/anaconda3/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# **Setup**
#
# Si la instalación de lightgbm da error, ejecutar en Anaconda Prompt
#
# `conda install -c conda-forge xgboost=1.4.0`
#
# `conda install -c conda-forge lightgbm=3.2.1`

# %% [markdown]
# ---
#
# <img src='../../../common/logo_DH.png' align='left' width=35%/>

# %% [markdown]
# ## Prediciendo quiebra de empresas - parte II

# %% [markdown]
# Continuando con el ejercicio del Checkpoint, usaremos ahora otros modelos de Boosting:
# - LightGBM
# - Catboost
#
# Ya hemos visto que XGBoost es una implementación de Gradient Boosting que busca mejorar su performance, y esto lo hace  mediante la aplicación de métodos de regularización para evitar sobreajustes.
#
# A continuación veremos otros dos implementaciones de Gradient Boosting que también buscan mejorar su performance cada uno con sus propias técnicas, pero principalmente trabajando sobre las técnicas de split.
#
# Cada uno de estos modelos tienen sus pros y cons. En este [link](https://medium.com/riskified-technology/xgboost-lightgbm-or-catboost-which-boosting-algorithm-should-i-use-e7fda7bb36bc) encontraremos una comparación detallada de cada uno de ellos.

# %%
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
df = pd.read_csv("../Data/3year.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7  \
# 0           0  0.174190  0.41299  0.14371  1.3480 -28.9820  0.60383  0.219460
# 1           1  0.146240  0.46038  0.28230  1.6294   2.5952  0.00000  0.171850
# 2           2  0.000595  0.22612  0.48839  3.1599  84.8740  0.19114  0.004572
# 3           3  0.024526  0.43236  0.27546  1.7833 -10.1050  0.56944  0.024526
# 4           4  0.188290  0.41504  0.34231  1.9279 -58.2740  0.00000  0.233580
#
#     Attr8   Attr9  ...    Attr56    Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1225  1.1961  ...  0.163960  0.375740  0.83604  0.000007  9.7145  6.2813
# 1  1.1721  1.6018  ...  0.027516  0.271000  0.90108  0.000000  5.9882  4.1103
# 2  2.9881  1.0077  ...  0.007639  0.000881  0.99236  0.000000  6.7742  3.7922
# 3  1.3057  1.0509  ...  0.048398  0.043445  0.95160  0.142980  4.2286  5.0528
# 4  1.4094  1.3393  ...  0.176480  0.321880  0.82635  0.073039  2.5912  7.0756
#
#     Attr62  Attr63  Attr64  class
# 0   84.291  4.3303  4.0341   b'0'
# 1  102.190  3.5716  5.9500   b'0'
# 2   64.846  5.6287  4.4581   b'0'
# 3   98.783  3.6950  3.4844   b'0'
# 4  100.540  3.6303  4.6375   b'0'
#
# [5 rows x 66 columns]

# %%
# eliminamos la primera columna que se trata de un indice.
df = df.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# Acá hay una descripción de los atributos
#
# - Attr1: net profit / total assets
# - Attr2: total liabilities / total assets
# - Attr3: working capital / total assets
# - Attr4: current assets / short-term liabilities
# - Attr5: [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365
# - Attr6: retained earnings / total assets
# - Attr7: EBIT / total assets
# - Attr8: book value of equity / total liabilities
# - Attr9: sales / total assets
# - Attr10: equity / total assets
# - Attr11: (gross profit + extraordinary items + financial expenses) / total assets
# - Attr12: gross profit / short-term liabilities
# - Attr13: (gross profit + depreciation) / sales
# - Attr14: (gross profit + interest) / total assets
# - Attr15: (total liabilities * 365) / (gross profit + depreciation)
# - Attr16: (gross profit + depreciation) / total liabilities
# - Attr17: total assets / total liabilities
# - Attr18: gross profit / total assets
# - Attr19: gross profit / sales
# - Attr20: (inventory * 365) / sales
# - Attr21: sales (n) / sales (n-1)
# - Attr22: profit on operating activities / total assets
# - Attr23: net profit / sales
# - Attr24: gross profit (in 3 years) / total assets
# - Attr25: (equity - share capital) / total assets
# - Attr26: (net profit + depreciation) / total liabilities
# - Attr27: profit on operating activities / financial expenses
# - Attr28: working capital / fixed assets
# - Attr29: logarithm of total assets
# - Attr30: (total liabilities - cash) / sales
# - Attr31: (gross profit + interest) / sales
# - Attr32: (current liabilities * 365) / cost of products sold
# - Attr33: operating expenses / short-term liabilities
# - Attr34: operating expenses / total liabilities
# - Attr35: profit on sales / total assets
# - Attr36: total sales / total assets
# - Attr37: (current assets - inventories) / long-term liabilities
# - Attr38: constant capital / total assets
# - Attr39: profit on sales / sales
# - Attr40: (current assets - inventory - receivables) / short-term liabilities
# - Attr41: total liabilities / ((profit on operating activities + depreciation) * (12/365))
# - Attr42: profit on operating activities / sales
# - Attr43: rotation receivables + inventory turnover in days
# - Attr44: (receivables * 365) / sales
# - Attr45: net profit / inventory
# - Attr46: (current assets - inventory) / short-term liabilities
# - Attr47: (inventory * 365) / cost of products sold
# - Attr48: EBITDA (profit on operating activities - depreciation) / total assets
# - Attr49: EBITDA (profit on operating activities - depreciation) / sales
# - Attr50: current assets / total liabilities
# - Attr51: short-term liabilities / total assets
# - Attr52: (short-term liabilities * 365) / cost of products sold)
# - Attr53: equity / fixed assets
# - Attr54: constant capital / fixed assets
# - Attr55: working capital
# - Attr56: (sales - cost of products sold) / sales
# - Attr57: (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)
# - Attr58: total costs /total sales
# - Attr59: long-term liabilities / equity
# - Attr60: sales / inventory
# - Attr61: sales / receivables
# - Attr62: (short-term liabilities *365) / sales
# - Attr63: sales / short-term liabilities
# - Attr64: sales / fixed assets
# - class: toma los valores "b'0'" y "b'1'" indicando si la empresa quebro o no.

# %% [markdown]
# ### Ejercicio 1
# 1) Obtener la `matriz de features X` y la `variable target y`
# 2) Analizar la forma (shape) del dataset.
# 3) Ver los valores que toma la variable target
# 4) Aplicar LabelEncoder sobre la variable target.

# %%
from sklearn.model_selection import StratifiedKFold

# %%
X = df.drop('class', axis=1)
y = df['class']

# %%
df.shape
# Out:
# (10503, 65)

# %%
y.value_counts(normalize=True)
# Out:
# b'0'    0.952871
# b'1'    0.047129
# Name: class, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

plt.figure(figsize=(8,6))

sns.countplot(x=df['class'])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

enc = LabelEncoder()
y = enc.fit_transform(y)

# %%
pd.Series(y).value_counts()
# Out:
# 0    10008
# 1      495
# dtype: int64

# %% [markdown]
# ### Ejercicio 2
# 1) Realizar un split en Train y Test, dejando un 20% para test
# 2) crear un generador de CV utilizando: `cv = StratifiedKFold(n_splits=5, random_state=41, shuffle=True)` para luego pasarselo tanto a `GridSearchCV` como a `cross_val_score`

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =\
train_test_split(X, y, stratify = y, shuffle =True, random_state = 1203, test_size = .2)

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV,cross_val_score

# %%
kfolds = StratifiedKFold(n_splits=5, shuffle=True, random_state=41)

# %% [markdown]
# ### Ejercicio 3: LightGBM
# 1) Importar el clasificador `LGBMClassifier()` de la libreria `lightgbm`.
#
# https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html#lightgbm.LGBMClassifier
#
# La lista completa de hiperparámetros se puede consultar [aquí](https://github.com/Microsoft/LightGBM/blob/master/docs/Parameters.rst)

# %%
from lightgbm import LGBMClassifier

# %%
lgbm = LGBMClassifier(importance_type='gain')

# %% [markdown]
# 2) Utilizando el siguiente diccionario de parametros, optimizar los hiperparámetros.
# 3) Imprimir en pantalla la mejor selección de hiperparámetros

# %%
from sklearn.model_selection import GridSearchCV
params = {  
    "n_estimators": [50,100,500],      # Number of boosted trees to fit.
    "max_depth": [1,2,3,4],            # Maximum tree depth for base learners.
    "learning_rate": [0.01, 0.1],      # Boosting learning rate (xgb’s “eta”)
    'is_unbalance':[True]              # Target muy desbalanceado
}

# %%
gs = GridSearchCV(lgbm, params, n_jobs=-1, cv=kfolds, scoring='f1')

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=41, shuffle=True),
#              estimator=LGBMClassifier(importance_type='gain'), n_jobs=-1,
#              param_grid={'is_unbalance': [True], 'learning_rate': [0.01, 0.1],
#                          'max_depth': [1, 2, 3, 4],
#                          'n_estimators': [50, 100, 500]},
#              scoring='f1')

# %%
gs.best_params_
# Out:
# {'is_unbalance': True,
#  'learning_rate': 0.1,
#  'max_depth': 4,
#  'n_estimators': 500}

# %%
best_lgbm = gs.best_estimator_

# %% [markdown]
# 5) Evaluar el rendimiento del estimador optimo, utilizando cross validation.
# (pasarle como argumento cv el generador de CV splits del creado en el punto 3)
# **nota:** ver función evaluar_rendimiento() utilizada en la notebook `2-Boosting_Practica.ipynb`

# %%
cv =cross_val_score(best_lgbm, X_train, y_train, scoring='f1', cv = kfolds, n_jobs=-1)
cv
# Out:
# array([0.62068966, 0.65693431, 0.5483871 , 0.60465116, 0.56      ])

# %%
# Performance en el set de validacion
cv.mean()
# Out:
# 0.5981324442613296

# %%
from sklearn.metrics import f1_score

f1_score(y_test, best_lgbm.predict(X_test))
# Out:
# 0.6588235294117647

# %% [markdown]
# 6) utilizando roc_auc_score de la libreria sklearn.metrics, determinar el valor del ROC.

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, best_lgbm.predict(X_test))
# Out:
# 0.7790820290820291

# %% [markdown]
# 7) utilizando plot_roc de la libreria sklearn.metrics, graficamos la curva ROC por clase

# %%
from scikitplot.metrics import plot_roc

plot_roc(y_test, best_lgbm.predict_proba(X_test), plot_micro = False, plot_macro= False);

# %% [markdown]
# ### BONUS:
# graficar la importancia de los atributos del estimador optimizado.
# **nota:** LightGBM tiene un método propio para graficar`plot_importance`

# %%
from lightgbm import plot_importance

plot_importance(best_lgbm, height = 0.8,max_num_features=5)
plt.show()

# %%
pd.DataFrame({'FEATURE':X.columns, 'IMPORTANCE':best_lgbm.feature_importances_}).sort_values('IMPORTANCE',ascending = False).head(5)
# Out:
#    FEATURE    IMPORTANCE
# 26  Attr27  26127.588148
# 20  Attr21  11741.999379
# 33  Attr34  11385.447843
# 24  Attr25   5467.756193
# 4    Attr5   5465.465322

# %% [markdown]
# ### Ejercicio 4: Catboost
# 1) Importar el clasificador `CatBoostClassifier()` de la libreria `catboost`.
#
# https://catboost.ai/docs/concepts/about.html

# %%
from catboost import CatBoostClassifier

# %% [markdown]
# 2) Con catboost los resultados sin optimizar hiperparámetros ya son excelentes. Procedemos a entrenar el modelo con los datos de training.

# %%
catbclf = CatBoostClassifier().fit(X_train, y_train)
# Out:
# Learning rate set to 0.025565
# 0:	learn: 0.6560026	total: 64.8ms	remaining: 1m 4s
# 1:	learn: 0.6223042	total: 69.1ms	remaining: 34.5s
# 2:	learn: 0.5882660	total: 73.7ms	remaining: 24.5s
# 3:	learn: 0.5585295	total: 78.3ms	remaining: 19.5s
# 4:	learn: 0.5313033	total: 82.2ms	remaining: 16.4s
# 5:	learn: 0.5054617	total: 86.1ms	remaining: 14.3s
# 6:	learn: 0.4789438	total: 90.1ms	remaining: 12.8s
# 7:	learn: 0.4508757	total: 94ms	remaining: 11.7s
# 8:	learn: 0.4306733	total: 98.1ms	remaining: 10.8s
# 9:	learn: 0.4121569	total: 103ms	remaining: 10.2s
# 10:	learn: 0.3954626	total: 107ms	remaining: 9.59s
# 11:	learn: 0.3795853	total: 110ms	remaining: 9.09s
# 12:	learn: 0.3653058	total: 114ms	remaining: 8.67s
# 13:	learn: 0.3518650	total: 118ms	remaining: 8.32s
# 14:	learn: 0.3370549	total: 122ms	remaining: 8.04s
# 15:	learn: 0.3257339	total: 127ms	remaining: 7.8s
# 16:	learn: 0.3153803	total: 131ms	remaining: 7.56s
# 17:	learn: 0.3048206	total: 134ms	remaining: 7.33s
# 18:	learn: 0.2961860	total: 138ms	remaining: 7.15s
# 19:	learn: 0.2839750	total: 142ms	remaining: 6.97s
# 20:	learn: 0.2732492	total: 147ms	remaining: 6.84s
# 723:	learn: 0.0368062	total: 3.29s	remaining: 1.25s
# 724:	learn: 0.0367757	total: 3.3s	remaining: 1.25s
# 725:	learn: 0.0367373	total: 3.3s	remaining: 1.25s
# 726:	learn: 0.0366419	total: 3.3s	remaining: 1.24s
# 727:	learn: 0.0366172	total: 3.31s	remaining: 1.24s
# 728:	learn: 0.0365679	total: 3.31s	remaining: 1.23s
# 729:	learn: 0.0365440	total: 3.32s	remaining: 1.23s
# 730:	learn: 0.0365253	total: 3.32s	remaining: 1.22s
# 731:	learn: 0.0365022	total: 3.33s	remaining: 1.22s
# 732:	learn: 0.0364321	total: 3.33s	remaining: 1.21s
# 733:	learn: 0.0364039	total: 3.33s	remaining: 1.21s
# 734:	learn: 0.0363917	total: 3.34s	remaining: 1.2s
# 735:	learn: 0.0363205	total: 3.34s	remaining: 1.2s
# 736:	learn: 0.0362981	total: 3.35s	remaining: 1.2s
# 737:	learn: 0.0362844	total: 3.35s	remaining: 1.19s
# 738:	learn: 0.0361712	total: 3.36s	remaining: 1.19s
# 739:	learn: 0.0361316	total: 3.36s	remaining: 1.18s
# 740:	learn: 0.0360825	total: 3.37s	remaining: 1.18s
# 741:	learn: 0.0360664	total: 3.37s	remaining: 1.17s
# 742:	learn: 0.0359920	total: 3.38s	remaining: 1.17s
# 743:	learn: 0.0359400	total: 3.38s	remaining: 1.16s
# 744:	learn: 0.0359114	total: 3.38s	remaining: 1.16s
# 745:	learn: 0.0358036	total: 3.39s	remaining: 1.15s
# 746:	learn: 0.0357837	total: 3.39s	remaining: 1.15s
# 747:	learn: 0.0357029	total: 3.4s	remaining: 1.14s
# 748:	learn: 0.0356476	total: 3.4s	remaining: 1.14s
# 749:	learn: 0.0356326	total: 3.4s	remaining: 1.13s
# 750:	learn: 0.0356015	total: 3.41s	remaining: 1.13s
# 751:	learn: 0.0355810	total: 3.41s	remaining: 1.13s
# 752:	learn: 0.0355404	total: 3.42s	remaining: 1.12s
# 753:	learn: 0.0355201	total: 3.42s	remaining: 1.11s
# 754:	learn: 0.0354359	total: 3.42s	remaining: 1.11s
# 755:	learn: 0.0354105	total: 3.43s	remaining: 1.11s
# 756:	learn: 0.0353694	total: 3.43s	remaining: 1.1s
# 757:	learn: 0.0353387	total: 3.44s	remaining: 1.1s
# 758:	learn: 0.0353278	total: 3.44s	remaining: 1.09s
# 759:	learn: 0.0352836	total: 3.44s	remaining: 1.09s
# 760:	learn: 0.0352113	total: 3.45s	remaining: 1.08s
# 761:	learn: 0.0351927	total: 3.45s	remaining: 1.08s
# 762:	learn: 0.0351313	total: 3.46s	remaining: 1.07s
# 763:	learn: 0.0350988	total: 3.46s	remaining: 1.07s
# 764:	learn: 0.0350224	total: 3.47s	remaining: 1.06s
# 765:	learn: 0.0349902	total: 3.47s	remaining: 1.06s
# 766:	learn: 0.0349624	total: 3.48s	remaining: 1.05s
# 767:	learn: 0.0349457	total: 3.48s	remaining: 1.05s
# 768:	learn: 0.0349342	total: 3.48s	remaining: 1.05s
# 960:	learn: 0.0275789	total: 4.32s	remaining: 175ms
# 961:	learn: 0.0275632	total: 4.32s	remaining: 171ms
# 962:	learn: 0.0275542	total: 4.33s	remaining: 166ms
# 963:	learn: 0.0275121	total: 4.33s	remaining: 162ms
# 964:	learn: 0.0274837	total: 4.33s	remaining: 157ms
# 965:	learn: 0.0274581	total: 4.34s	remaining: 153ms
# 966:	learn: 0.0274268	total: 4.34s	remaining: 148ms
# 967:	learn: 0.0274019	total: 4.35s	remaining: 144ms
# 968:	learn: 0.0273544	total: 4.35s	remaining: 139ms
# 969:	learn: 0.0273332	total: 4.36s	remaining: 135ms
# 970:	learn: 0.0273140	total: 4.36s	remaining: 130ms
# 971:	learn: 0.0272889	total: 4.37s	remaining: 126ms
# 972:	learn: 0.0272536	total: 4.37s	remaining: 121ms
# 973:	learn: 0.0272361	total: 4.38s	remaining: 117ms
# 974:	learn: 0.0271899	total: 4.38s	remaining: 112ms
# 975:	learn: 0.0271570	total: 4.39s	remaining: 108ms
# 976:	learn: 0.0271241	total: 4.39s	remaining: 103ms
# 977:	learn: 0.0271001	total: 4.4s	remaining: 98.9ms
# 978:	learn: 0.0270941	total: 4.4s	remaining: 94.4ms
# 979:	learn: 0.0270860	total: 4.41s	remaining: 90ms
# 980:	learn: 0.0270761	total: 4.41s	remaining: 85.5ms
# 981:	learn: 0.0270668	total: 4.42s	remaining: 81ms
# 982:	learn: 0.0270484	total: 4.42s	remaining: 76.5ms
# 983:	learn: 0.0270318	total: 4.43s	remaining: 72ms
# 984:	learn: 0.0269888	total: 4.43s	remaining: 67.5ms
# 985:	learn: 0.0269551	total: 4.43s	remaining: 63ms
# 986:	learn: 0.0269225	total: 4.44s	remaining: 58.5ms
# 987:	learn: 0.0268713	total: 4.45s	remaining: 54ms
# 988:	learn: 0.0268323	total: 4.45s	remaining: 49.5ms
# 989:	learn: 0.0268251	total: 4.46s	remaining: 45ms
# 990:	learn: 0.0267925	total: 4.46s	remaining: 40.5ms
# 991:	learn: 0.0267479	total: 4.46s	remaining: 36ms
# 992:	learn: 0.0267411	total: 4.47s	remaining: 31.5ms
# 993:	learn: 0.0267025	total: 4.47s	remaining: 27ms
# 994:	learn: 0.0266851	total: 4.48s	remaining: 22.5ms
# 995:	learn: 0.0266745	total: 4.48s	remaining: 18ms
# 996:	learn: 0.0266367	total: 4.49s	remaining: 13.5ms
# 997:	learn: 0.0266308	total: 4.49s	remaining: 9ms
# 998:	learn: 0.0265774	total: 4.5s	remaining: 4.5ms
# 999:	learn: 0.0265349	total: 4.5s	remaining: 0us

# %% [markdown]
# 3) Una vez entrenado el modelo, realizar las predicciones sobre el dataset de prueba.

# %%
y_pred = catbclf.predict(X_test)

# %% [markdown]
# 4) utilizando roc_auc_score de la libreria sklearn.metrics, determinar el valor del ROC.

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 0.7113719613719615

# %% [markdown]
# 5) utilizando plot_roc de la libreria sklearn.metrics, graficamos la curva ROC por clase

# %%
plot_roc(y_test, catbclf.predict_proba(X_test), plot_micro = False, plot_macro= False);
